# %% [markdown]
# # SIEM ML Demo Notebook
# Isolation Forest pipeline demo using the 10-row sample dataset.

# %%
import pandas as pd
pd.read_csv('data/sample_dataset.csv').head()

# %%
from src.preprocess import preprocess_and_save
preprocess_and_save()

# %%
from src.train_iforest import train_iforest
model = train_iforest()

# %%
from src.evaluate_model import evaluate
evaluate()

# %%
import pandas as pd
pd.read_csv('data/processed/eval_results.csv').head()
